# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('sumanth.csv')
data
# Out:
#                 time      ax      ay      az      wx      wy      wz  \
# 0       19:43:20:966  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 1       19:43:20:968  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 2       19:43:20:969  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# 3       19:43:20:970  0.0000  0.0000  0.0000  0.0253 -0.0089 -0.0621
# 4       19:43:20:971  0.0000  0.0000  0.0000  0.0253 -0.0089 -0.0621
# ...              ...     ...     ...     ...     ...     ...     ...
# 141847  19:55:57:806 -0.3866 -0.6794 -0.9771 -0.0151 -0.0448  0.0129
# 141848  19:55:57:807 -0.3866 -0.6794 -0.9771 -0.0151 -0.0448  0.0129
# 141849  19:55:57:809 -0.4414 -0.0726  0.2412 -0.0151 -0.0448  0.0129
# 141850  19:55:57:812 -0.4414 -0.0726  0.2412 -0.0151 -0.0448  0.0129
# 141851  19:55:57:813 -0.4414 -0.0726  0.2412 -0.0151 -0.0448  0.0129
#
#         Latitude  Longitude  Speed (m/s)  Unnamed: 10
# 0        0.00000   0.000000     0.000000          NaN
# 1       17.44573  78.351242     1.837044          NaN
# 2       17.44573  78.351242     1.837044          NaN
# 3       17.44573  78.351242     1.837044          NaN
# 4       17.44573  78.351242     1.837044          NaN
# ...          ...        ...          ...          ...
# 141847  17.44512  78.350592     1.284747          NaN
# 141848  17.44512  78.350592     1.284747          NaN
# 141849  17.44512  78.350592     1.284747          NaN
# 141850  17.44512  78.350592     1.284747          NaN
# 141851  17.44512  78.350592     1.284747          NaN
#
# [141852 rows x 11 columns]

# %%
# pre_t = data['time']

# lt = len(pre_t)
# t = [0]

# for i in range(1, lt):
#   if int(pre_t[i][-3:]) > int(pre_t[i-1][-3:]):
#     x = abs((int(pre_t[i][-3:]) - int(pre_t[i-1][-3:])))/1000
#     #t.append((x + t[i-1]))
#   else:
#     x = abs((int(pre_t[i][-3:]) + 1000 - int(pre_t[i-1][-3:])))/1000
#   t.append(np.round((x + t[i-1]), 3))

# %%
# df = pd.DataFrame (t)

# ## save to xlsx file

# filepath = 'my_excel_file.xlsx'

# df.to_excel(filepath, index=False)

# %%
ax = data['ax']
ay = data['ay']
az = data['az']
gx = data['wx']
gy = data['wy']
gz = data['wz']

# %%
plt.figure(figsize=(15,5))

plt.plot(ax, label='Ax')
plt.plot(ay, label='Ay')
plt.plot(az, label='Az')

plt.legend()

# %%
plt.figure(figsize=(15,5))

#plt.plot(t, ax)
plt.plot(ax)
plt.title('Ax')
plt.show()

# %%
plt.figure(figsize=(15,5))

#plt.plot(t, ay)
plt.plot(ay)
plt.title('Ay')
plt.show()

# %%
plt.figure(figsize=(15,5))

#plt.plot(t, az)
plt.plot(az)
plt.title('Az')
plt.show()

# %%
plt.figure(figsize=(15,5))

#plt.plot(t, gx)
plt.plot(gx)
plt.title('Gx')
plt.show()

# %%
plt.figure(figsize=(15,5))

#plt.plot(t, gy)
plt.plot(gy)
plt.title('Gy')
plt.show()

# %%
plt.figure(figsize=(15,5))

#plt.plot(t, gz)
plt.plot(gz)
plt.title('Gz')
plt.show()
